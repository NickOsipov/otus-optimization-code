# %% [markdown]
# # Numba

# %%
import numpy as np
from numba import jit
from numpy.typing import ArrayLike

# %%
def without_numba(x: ArrayLike) -> ArrayLike:
    trace = .0
    for i in range(x.shape[0]):
        trace += np.tanh(x[i, i])
    return x + trace

# %%
@jit(nopython=True)
def with_numba(x: ArrayLike) -> ArrayLike:
    trace = .0
    for i in range(x.shape[0]):
        trace += np.tanh(x[i, i])
    return x + trace

# %%
x = np.arange(1000000).reshape(1000, 1000)

# %% [markdown]
# Первый запуск

# %%
# %%time
_ = without_numba(x)
# Out:
# CPU times: user 12.4 ms, sys: 29 μs, total: 12.4 ms
# Wall time: 10.3 ms

# %%
# %%time
_ = without_numba(x)
# Out:
# CPU times: user 12.4 ms, sys: 29 μs, total: 12.4 ms
# Wall time: 11.7 ms

# %% [markdown]
# Первый запуск numba компилирует функцию, что занимает время. Поэтому первый запуск будет медленнее, чем последующие.

# %%
# %%time
_ = with_numba(x)
# Out:
# CPU times: user 1.38 s, sys: 47.9 ms, total: 1.42 s
# Wall time: 1.47 s

# %%
# %%time
_ = with_numba(x)
# Out:
# CPU times: user 4.5 ms, sys: 21 μs, total: 4.52 ms
# Wall time: 4.42 ms

# %% [markdown]
# Второй запуск значительно быстрее, так как функция уже скомпилирована

# %%
# %%timeit
_ = with_numba(x)
# Out:
# 2.86 ms ± 220 μs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %%
# %%timeit
_ = with_numba(x)
# Out:
# 2.51 ms ± 84.1 μs per loop (mean ± std. dev. of 7 runs, 100 loops each)
